# %%
import mysql.connector as ms
import pandas as pd

# %%
pwd
# Out:
# '/Users/pixghosh/Library/CloudStorage/OneDrive-Personal/GradSchool/databases/classwork'

# %%
con = ms.connect(host = 'localhost', user = 'root', password = 'shreyoshi',database = 'Chinook')

# %%
employee_df = pd.read_sql('select * from employee', con)

# %%
employee_df.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  BirthDate  \
# 0           1    Adams    Andrew      General Manager        NaN 1962-02-18
# 1           2  Edwards     Nancy        Sales Manager        1.0 1958-12-08
# 2           3  Peacock      Jane  Sales Support Agent        2.0 1973-08-29
# 3           4     Park  Margaret  Sales Support Agent        2.0 1947-09-19
# 4           5  Johnson     Steve  Sales Support Agent        2.0 1965-03-03
#
#     HireDate              Address      City State Country PostalCode  \
# 0 2002-08-14  11120 Jasper Ave NW  Edmonton    AB  Canada    T5K 2N1
# 1 2002-05-01         825 8 Ave SW   Calgary    AB  Canada    T2P 2T3
# 2 2002-04-01        1111 6 Ave SW   Calgary    AB  Canada    T2P 5M5
# 3 2003-05-03     683 10 Street SW   Calgary    AB  Canada    T2P 5G3
# 4 2003-10-17         7727B 41 Ave   Calgary    AB  Canada    T3B 1Y7
#
#                Phone                Fax                     Email
# ...

# %%
con.close()

# %%
cursor = con.cursor()
cursor.execute('select * from employee')
results = cursor.fetchall()
for row in results:
    print(row[1])
# Out:
# Adams
# Edwards
# Peacock
# Park
# Johnson
# Mitchell
# King
# Callahan

# %%
cursor.close()
con.close()

# %%
con = ms.connect(host = 'genome-mysql.cse.ucsc.edu', user = 'genome',database = 'hg19')

# %%
cursor = con.cursor()
cursor.execute('show tables')
results = cursor.fetchall()
for r in results:
    print(r)
# Out:
# ('HInv',)
# ('HInvGeneMrna',)
# ('acembly',)
# ('acemblyClass',)
# ('acemblyPep',)
# ('affyCytoScan',)
# ('affyExonProbeAmbiguous',)
# ('affyExonProbeCore',)
# ('affyExonProbeExtended',)
# ('affyExonProbeFree',)
# ('affyExonProbeFull',)
# ('affyExonProbesetAmbiguous',)
# ('affyExonProbesetCore',)
# ('affyExonProbesetExtended',)
# ('affyExonProbesetFree',)
# ('affyExonProbesetFull',)
# ('affyGnf1h',)
# ('affyU133',)
# ('affyU133Plus2',)
# ('affyU95',)
# ('agilentCgh1x1m',)
# ('agilentCgh1x244k',)
# ('agilentCgh2x105k',)
# ('agilentCgh2x400k',)
# ('agilentCgh4x180k',)
# ('agilentCgh4x44k',)
# ('agilentCgh8x60k',)
# ('agilentCghSnp2x400k',)
# ('agilentCghSnp4x180k',)
# ('agilentCghSnpCancer4x180k',)
# ('agilentHrd1x1m',)
# ('allHg19RS_BW',)
# ('all_bacends',)
# ('all_est',)
# ('all_fosends',)
# ('all_mrna',)
# ('all_sts_primer',)
# ('all_sts_seq',)
# ('allenBrainAli',)
# ('allenBrainGene',)
# ('allenBrainUrl',)
# ('altLocations',)
# ('altSeqHaplotypesP9',)
# ('altSeqLiftOverPsl',)
# ...
